# %%
#imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# # <font color="red">Replace the word "template" with your name in the filename and remove this label.</font>
#
# # Electron Diffraction to Measure Atomic Lattices
# by Physics Student
#
# ## Introduction
#
# ### Historical Context
# Give historical context about de Broglie's prediction of particles acting like waves and the later experimental work of George Paget Thomson and Clinton Joseph Davisson.
#
# ## Experimental Procedure
# * How is experiment set up?
#     * Show a labeled diagram with experimental constants and variables.
#     * What are the constants set by the apparatus?
#     * What parameters are variable?
#     * What variables are going to be set as constant?
#     * What variables are going to be dependent and independent?
#
# ### Mathematical
# Show mathematically that you can extract the atomic spacing in graphite by assuming electrons behave as waves when they have kinetic energy. Your result will be
#
# $$\lambda = \frac{dR}{L}$$
#
# where
#
# $$\lambda = \frac{h}{\sqrt{2meV}}$$
#
# A graph of $R$ vs. $\lambda$ will be linear with a slope of
#
# $${\rm slope} = \frac{d}{L}$$
#
#
# * Explain how you will electrically connect everything and why.
# * Explain the constants and dependent variables settings you must make.
# * Describe the data that you collect.
# * How does the apparatus measure the atom (lattice) spacings?
# * Make figures of your own like the ones below.
#
# <img src="./images/Bragg.png" alt="Bragg diffraction of a hexagonal lattice" width="600">
# <img src="./images/Lattice.png" alt="Hexagonal lattice spacings measured by diffractometer" width="600">
#
# ## Results and Analysis
# Explain what you did with the results to determine $d_1$ and $d_2$.

# %%
# Raw Data
L = #distance from graphite to screen
ee = #electron charge
V = np.array([])#array of voltage that accelerates the beam of electrons
wl = #array of electron wavelengths calculated from V
DS = np.array([])#array of small diffraction ring diameters
DL = np.array([])#array of large diffraction ring diameters
errDS = np.array([])#array of uncertainties in small diffraction ring diameters
errDL = np.array([])#array of uncertainties in large diffraction ring diameters
dgS = np.array([]) #calculated lattice spacing for small diffraction rings
dgL = np.array([]) #calculated lattice spacing for large diffraction rings

#linear fit function
def f_line(x, m, b):
    return m*x + b

#Fit the line to your data
#NOTE: You will need to do the fit for both rings.
#Rename the fit_ values and do the curve_fit twice
m = #initial guess at the slope
b = #initial guess at the intercept
fit_params, fit_cov = curve_fit(f_line, V_2, theta, (m,b))
#fit_params = [slope, intercept]
#fit_cov = uncertainties squared
print(fit_params, fit_cov)

#Create a fit array from the fit_params
#slope = fit_params[0]
#intercept = fit_params[1]
fit_y = #m*x + b

#Graph the results by filling in all the appropriate details
#You will have two plt.errorbar commands, one for each ring
plt.errorbar(x, y, yerr=errDS, fmt='or', capsize=5.0, capthick=1.0, label='')#plot the data
plt.plot(x, fity, 'marker', label='')#plot the fit
plt.xlabel('')
plt.ylabel('')
plt.legend()
plt.show()

# %% [markdown]
# **Note that the `fit_cov` matrix is called the covariant matrix. It can be written as**
#
# $$
# {\rm fit\_cov} = \begin{pmatrix}
# \sigma^2_m & \sigma^2_{mb}\\
# \sigma^2_{bm} & \sigma^2_b
# \end{pmatrix}
# $$
#
# In this matrix the diagonals (`fit_cov[0,0]` and `fit_cov[1,1]`) are the squares of the uncertainty in your slope and intercept. You will need to propagate this uncertainty and any uncertainty in other variables and constants so that you can report a final
#
# $$d_1 = {\rm value \pm uncertainty}\\
# d_2 = {\rm value \pm uncertainty}
# $$
#
# Explain your process.
#
# ## Conclusions
# * What is the value of $d_1$ and $d_2$ from your experiment including uncertainty propagated from the slope and including slope uncertainty and uncertainties in other experimental variables and constants?
# * How does your result compare with the previously know values of $d_1$ and $d_2$?
# * How could you improve the experiment?
#     * Is there a way to reduce the uncertainty?
#     * Is there a better way to measure the ring diameters?
